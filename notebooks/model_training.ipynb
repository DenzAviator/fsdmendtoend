# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("./data/diamond.csv.CSV")

# %%
data.head()
# Out:
#    Unnamed: 0  carat        cut color clarity  depth  table     x     y     z  \
# 0           1   0.30      Ideal     E     SI1   62.1   58.0  4.27  4.29  2.66
# 1           2   0.33    Premium     G      IF   60.8   58.0  4.42  4.46  2.70
# 2           3   0.90  Very Good     E    VVS2   62.2   60.0  6.04  6.12  3.78
# 3           4   0.42      Ideal     F     VS1   61.6   56.0  4.82  4.80  2.96
# 4           5   0.31      Ideal     F    VVS1   60.4   59.0  4.35  4.43  2.65
#
#    price
# 0    499
# 1    984
# 2   6289
# 3   1082
# 4    779

# %%
data=data.drop(labels=["Unnamed: 0"],axis=1)

# %%
data
# Out:
#        carat        cut color clarity  depth  table     x     y     z  price
# 0       0.30      Ideal     E     SI1   62.1   58.0  4.27  4.29  2.66    499
# 1       0.33    Premium     G      IF   60.8   58.0  4.42  4.46  2.70    984
# 2       0.90  Very Good     E    VVS2   62.2   60.0  6.04  6.12  3.78   6289
# 3       0.42      Ideal     F     VS1   61.6   56.0  4.82  4.80  2.96   1082
# 4       0.31      Ideal     F    VVS1   60.4   59.0  4.35  4.43  2.65    779
# ...      ...        ...   ...     ...    ...    ...   ...   ...   ...    ...
# 26962   1.11    Premium     G     SI1   62.3   58.0  6.61  6.52  4.09   5408
# 26963   0.33      Ideal     H      IF   61.9   55.0  4.44  4.42  2.74   1114
# 26964   0.51    Premium     E     VS2   61.7   58.0  5.12  5.15  3.17   1656
# 26965   0.27  Very Good     F    VVS2   61.8   56.0  4.19  4.20  2.60    682
# 26966   1.25    Premium     J     SI1   62.0   58.0  6.90  6.88  4.27   5166
#
# [26967 rows x 10 columns]

# %%
x=data.drop(columns="price",axis=1)
y=data[["price"]]

# %%
x
# Out:
#        carat        cut color clarity  depth  table     x     y     z
# 0       0.30      Ideal     E     SI1   62.1   58.0  4.27  4.29  2.66
# 1       0.33    Premium     G      IF   60.8   58.0  4.42  4.46  2.70
# 2       0.90  Very Good     E    VVS2   62.2   60.0  6.04  6.12  3.78
# 3       0.42      Ideal     F     VS1   61.6   56.0  4.82  4.80  2.96
# 4       0.31      Ideal     F    VVS1   60.4   59.0  4.35  4.43  2.65
# ...      ...        ...   ...     ...    ...    ...   ...   ...   ...
# 26962   1.11    Premium     G     SI1   62.3   58.0  6.61  6.52  4.09
# 26963   0.33      Ideal     H      IF   61.9   55.0  4.44  4.42  2.74
# 26964   0.51    Premium     E     VS2   61.7   58.0  5.12  5.15  3.17
# 26965   0.27  Very Good     F    VVS2   61.8   56.0  4.19  4.20  2.60
# 26966   1.25    Premium     J     SI1   62.0   58.0  6.90  6.88  4.27
#
# [26967 rows x 9 columns]

# %%
y
# Out:
#        price
# 0        499
# 1        984
# 2       6289
# 3       1082
# 4        779
# ...      ...
# 26962   5408
# 26963   1114
# 26964   1656
# 26965    682
# 26966   5166
#
# [26967 rows x 1 columns]

# %%
data.isnull().sum()
# Out:
# carat        0
# cut          0
# color        0
# clarity      0
# depth      697
# table        0
# x            0
# y            0
# z            0
# price        0
# dtype: int64

# %%
data["depth"].fillna(data["depth"].mean(),inplace=True)

# %%
data.duplicated().sum()
# Out:
# 34

# %%
data.drop_duplicates(inplace=True)

# %%
x=data.drop(labels=["price"],axis=1)

# %%
y=data[["price"]]

# %%
x
# Out:
#        carat        cut color clarity  depth  table     x     y     z
# 0       0.30      Ideal     E     SI1   62.1   58.0  4.27  4.29  2.66
# 1       0.33    Premium     G      IF   60.8   58.0  4.42  4.46  2.70
# 2       0.90  Very Good     E    VVS2   62.2   60.0  6.04  6.12  3.78
# 3       0.42      Ideal     F     VS1   61.6   56.0  4.82  4.80  2.96
# 4       0.31      Ideal     F    VVS1   60.4   59.0  4.35  4.43  2.65
# ...      ...        ...   ...     ...    ...    ...   ...   ...   ...
# 26962   1.11    Premium     G     SI1   62.3   58.0  6.61  6.52  4.09
# 26963   0.33      Ideal     H      IF   61.9   55.0  4.44  4.42  2.74
# 26964   0.51    Premium     E     VS2   61.7   58.0  5.12  5.15  3.17
# 26965   0.27  Very Good     F    VVS2   61.8   56.0  4.19  4.20  2.60
# 26966   1.25    Premium     J     SI1   62.0   58.0  6.90  6.88  4.27
#
# [26933 rows x 9 columns]

# %%
y
# Out:
#        price
# 0        499
# 1        984
# 2       6289
# 3       1082
# 4        779
# ...      ...
# 26962   5408
# 26963   1114
# 26964   1656
# 26965    682
# 26966   5166
#
# [26933 rows x 1 columns]

# %%
x.select_dtypes(include="object").columns
# Out:
# Index(['cut', 'color', 'clarity'], dtype='object')

# %%
categorical_col=x.select_dtypes(include="object").columns

# %%
x.select_dtypes(exclude="object").columns
# Out:
# Index(['carat', 'depth', 'table', 'x', 'y', 'z'], dtype='object')

# %%
numerical_col=x.select_dtypes(exclude="object").columns

# %%
data.isnull
# Out:
# <bound method DataFrame.isnull of        carat        cut color clarity  depth  table     x     y     z  price
# 0       0.30      Ideal     E     SI1   62.1   58.0  4.27  4.29  2.66    499
# 1       0.33    Premium     G      IF   60.8   58.0  4.42  4.46  2.70    984
# 2       0.90  Very Good     E    VVS2   62.2   60.0  6.04  6.12  3.78   6289
# 3       0.42      Ideal     F     VS1   61.6   56.0  4.82  4.80  2.96   1082
# 4       0.31      Ideal     F    VVS1   60.4   59.0  4.35  4.43  2.65    779
# ...      ...        ...   ...     ...    ...    ...   ...   ...   ...    ...
# 26962   1.11    Premium     G     SI1   62.3   58.0  6.61  6.52  4.09   5408
# 26963   0.33      Ideal     H      IF   61.9   55.0  4.44  4.42  2.74   1114
# 26964   0.51    Premium     E     VS2   61.7   58.0  5.12  5.15  3.17   1656
# 26965   0.27  Very Good     F    VVS2   61.8   56.0  4.19  4.20  2.60    682
# 26966   1.25    Premium     J     SI1   62.0   58.0  6.90  6.88  4.27   5166
#
# [26933 rows x 10 columns]>

# %%
x.select_dtypes(include="object")
# Out:
#              cut color clarity
# 0          Ideal     E     SI1
# 1        Premium     G      IF
# 2      Very Good     E    VVS2
# 3          Ideal     F     VS1
# 4          Ideal     F    VVS1
# ...          ...   ...     ...
# 26962    Premium     G     SI1
# 26963      Ideal     H      IF
# 26964    Premium     E     VS2
# 26965  Very Good     F    VVS2
# 26966    Premium     J     SI1
#
# [26933 rows x 3 columns]

# %%
# define the customranking for each ordinal variable
cut_categories=["Fair","Good","Very Good","Premium","Ideal"]
color_categories=["D","E","F","G","H","I","J"]
clarity_categories=["I1","SI2", "SI1", "VS2", "VS1", "VVS2","VVS1","IF"]

# %%
from sklearn.impute import SimpleImputer ## Handling missing values
from sklearn.preprocessing import StandardScaler ##Handling Feature Scaling
from sklearn.preprocessing import OrdinalEncoder ##Ordinal Encoding
##pipelines
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# %%
num_pipeline=Pipeline(
    
    
    steps=[
        
        ("imputer",SimpleImputer()),
        ("scaler",StandardScaler())
        
    ]
)

# %%
cat_pipeline=Pipeline(
    
    
    steps=[
        
        ("imputer",SimpleImputer(strategy="most_frequent")),
        ("ordinaencoder",OrdinalEncoder(categories=[cut_categories,color_categories,clarity_categories]))
    ]
)

# %%
preprocessor=ColumnTransformer(
    
    
    [
        ("num_pipeline", num_pipeline,numerical_col),
        ("cat_pipeline", cat_pipeline,categorical_col)
    ]
)

# %%
## Train test split

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=30)

# %%
preprocessor.fit_transform(x_train)
# Out:
# array([[ 2.57516974e+00,  1.07590425e-01, -2.00453030e-01, ...,
#          4.00000000e+00,  4.00000000e+00,  1.00000000e+00],
#        [-8.78158722e-01,  1.07590425e-01, -1.10204094e+00, ...,
#          4.00000000e+00,  2.00000000e+00,  3.00000000e+00],
#        [-8.36300195e-01, -8.97314988e-01,  2.50340926e-01, ...,
#          2.00000000e+00,  0.00000000e+00,  3.00000000e+00],
#        ...,
#        [ 4.61314136e-01,  1.79369383e-01, -6.51246986e-01, ...,
#          4.00000000e+00,  0.00000000e+00,  5.00000000e+00],
#        [-1.04559283e+00,  1.04071688e+00, -2.00453030e-01, ...,
#          1.00000000e+00,  0.00000000e+00,  1.00000000e+00],
#        [-1.04559283e+00, -3.56176414e-03, -1.10204094e+00, ...,
#          4.00000000e+00,  4.00000000e+00,  5.00000000e+00]])

# %%
x_train
# Out:
#        carat        cut color clarity      depth  table     x     y     z
# 11094   2.03      Ideal     H     SI2  61.900000   57.0  8.14  8.10  5.03
# 23218   0.38      Ideal     F     VS2  61.900000   55.0  4.69  4.63  2.89
# 16067   0.40  Very Good     D     VS2  60.500000   58.0  4.76  4.82  2.90
# 485     1.52    Premium     E     SI1  62.500000   59.0  7.33  7.26  4.56
# 7830    1.00       Fair     H     SI2  67.800000   53.0  6.08  6.02  4.10
# ...      ...        ...   ...     ...        ...    ...   ...   ...   ...
# 500     0.71    Premium     G     SI1  58.900000   62.0  5.85  5.79  3.43
# 12084   0.50      Ideal     I    VVS2  60.500000   57.0  5.14  5.17  3.12
# 15289   1.02      Ideal     D    VVS2  62.000000   56.0  6.48  6.43  4.00
# 4517    0.30       Good     D     SI2  63.200000   57.0  4.21  4.24  2.67
# 5926    0.30      Ideal     H    VVS2  61.745147   55.0  4.28  4.25  2.67
#
# [18853 rows x 9 columns]

# %%
x_test
# Out:
#        carat        cut color clarity  depth  table     x     y     z
# 30      1.19      Ideal     G     SI1   62.3   55.0  6.76  6.81  4.23
# 4375    0.36  Very Good     E     SI1   62.9   56.0  4.52  4.57  2.86
# 20051   1.56       Good     J     VS2   62.3   64.0  7.41  7.36  4.60
# 24277   0.40    Premium     F     VS1   60.5   60.0  4.76  4.80  2.89
# 25197   1.07    Premium     H     VS2   58.9   58.0  6.70  6.65  3.93
# ...      ...        ...   ...     ...    ...    ...   ...   ...   ...
# 14400   1.51    Premium     F     SI1   60.9   61.0  7.32  7.30  4.45
# 4949    0.75       Good     F     VS1   64.4   59.0  5.67  5.72  3.66
# 627     0.35  Very Good     E     VS1   62.3   60.0  4.50  4.52  2.81
# 24291   1.06  Very Good     H     SI1   62.2   58.0  6.45  6.53  4.04
# 19508   0.52    Premium     E     VS2   62.5   56.0  5.18  5.15  3.23
#
# [8080 rows x 9 columns]

# %%
y_train
# Out:
#        price
# 11094  11379
# 23218    969
# 16067    720
# 485    12418
# 7830    2530
# ...      ...
# 500     2181
# 12084   1640
# 15289  11167
# 4517     447
# 5926     776
#
# [18853 rows x 1 columns]

# %%
y_test
# Out:
#        price
# 30      6335
# 4375     631
# 20051   8107
# 24277    982
# 25197   4830
# ...      ...
# 14400  11666
# 4949    2953
# 627      829
# 24291   4878
# 19508   1815
#
# [8080 rows x 1 columns]

# %%
data.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# x          0
# y          0
# z          0
# price      0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
preprocessor.transform(x_train)
# Out:
# array([[ 2.57516974e+00,  1.07590425e-01, -2.00453030e-01, ...,
#          4.00000000e+00,  4.00000000e+00,  1.00000000e+00],
#        [-8.78158722e-01,  1.07590425e-01, -1.10204094e+00, ...,
#          4.00000000e+00,  2.00000000e+00,  3.00000000e+00],
#        [-8.36300195e-01, -8.97314988e-01,  2.50340926e-01, ...,
#          2.00000000e+00,  0.00000000e+00,  3.00000000e+00],
#        ...,
#        [ 4.61314136e-01,  1.79369383e-01, -6.51246986e-01, ...,
#          4.00000000e+00,  0.00000000e+00,  5.00000000e+00],
#        [-1.04559283e+00,  1.04071688e+00, -2.00453030e-01, ...,
#          1.00000000e+00,  0.00000000e+00,  1.00000000e+00],
#        [-1.04559283e+00, -3.56176414e-03, -1.10204094e+00, ...,
#          4.00000000e+00,  4.00000000e+00,  5.00000000e+00]])

# %%
preprocessor.get_feature_names_out()
# Out:
# array(['num_pipeline__carat', 'num_pipeline__depth',
#        'num_pipeline__table', 'num_pipeline__x', 'num_pipeline__y',
#        'num_pipeline__z', 'cat_pipeline__cut', 'cat_pipeline__color',
#        'cat_pipeline__clarity'], dtype=object)

# %%
x_train=pd.DataFrame(preprocessor.fit_transform(x_train),columns=preprocessor.get_feature_names_out())
x_test=pd.DataFrame(preprocessor.transform(x_test),columns=preprocessor.get_feature_names_out())

# %%
x_train
# Out:
#        num_pipeline__carat  num_pipeline__depth  num_pipeline__table  \
# 0                 2.575170             0.107590            -0.200453
# 1                -0.878159             0.107590            -1.102041
# 2                -0.836300            -0.897315             0.250341
# 3                 1.507777             0.538264             0.701135
# 4                 0.419456             4.342549            -2.003629
# ...                    ...                  ...                  ...
# 18848            -0.187493            -2.045778             2.053517
# 18849            -0.627008            -0.897315            -0.200453
# 18850             0.461314             0.179369            -0.651247
# 18851            -1.045593             1.040717            -0.200453
# 18852            -1.045593            -0.003562            -1.102041
#
#        num_pipeline__x  num_pipeline__y  num_pipeline__z  cat_pipeline__cut  \
# 0             2.136790         2.115004         2.044480                4.0
# 1            -0.925939        -0.987762        -0.892720                4.0
# 2            -0.863796        -0.817870        -0.878994                2.0
# 3             1.417715         1.363902         1.399394                3.0
# 4             0.308030         0.255133         0.768033                0.0
# ...                ...              ...              ...                ...
# 18848         0.103849         0.049474        -0.151557                3.0
# 18849        -0.526452        -0.504911        -0.577039                4.0
# 18850         0.663129         0.621742         0.630781                4.0
# 18851        -1.352057        -1.336487        -1.194675                1.0
# 18852        -1.289915        -1.327546        -1.194675                4.0
#
#        cat_pipeline__color  cat_pipeline__clarity
# 0                      4.0                    1.0
# 1                      2.0                    3.0
# 2                      0.0                    3.0
# 3                      1.0                    2.0
# 4                      4.0                    1.0
# ...                    ...                    ...
# 18848                  3.0                    2.0
# 18849                  5.0                    5.0
# 18850                  0.0                    5.0
# 18851                  0.0                    1.0
# 18852                  4.0                    5.0
#
# [18853 rows x 9 columns]

# %%
x_test
# Out:
#       num_pipeline__carat  num_pipeline__depth  num_pipeline__table  \
# 0                0.817112             0.394706            -1.102041
# 1               -0.920017             0.825380            -0.651247
# 2                1.591494             0.394706             2.955105
# 3               -0.836300            -0.897315             1.151929
# 4                0.565960            -2.045778             0.250341
# ...                   ...                  ...                  ...
# 8075             1.486848            -0.610199             1.602723
# 8076            -0.103776             1.902064             0.701135
# 8077            -0.940947             0.394706             1.151929
# 8078             0.545031             0.322927             0.250341
# 8079            -0.585149             0.538264            -0.651247
#
#       num_pipeline__x  num_pipeline__y  num_pipeline__z  cat_pipeline__cut  \
# 0            0.911699         0.961526         0.946461                4.0
# 1           -1.076856        -1.041412        -0.933895                2.0
# 2            1.488735         1.453319         1.454295                1.0
# 3           -0.863796        -0.835753        -0.892720                3.0
# 4            0.858434         0.818459         0.534705                3.0
# ...               ...              ...              ...                ...
# 8075         1.408837         1.399669         1.248417                3.0
# 8076        -0.055946        -0.013118         0.164123                1.0
# 8077        -1.094611        -1.086120        -1.002521                2.0
# 8078         0.636497         0.711159         0.685682                2.0
# 8079        -0.490942        -0.522794        -0.426062                3.0
#
#       cat_pipeline__color  cat_pipeline__clarity
# 0                     3.0                    2.0
# 1                     1.0                    2.0
# 2                     6.0                    3.0
# 3                     2.0                    4.0
# 4                     4.0                    3.0
# ...                   ...                    ...
# 8075                  2.0                    2.0
# 8076                  2.0                    4.0
# 8077                  1.0                    4.0
# 8078                  4.0                    2.0
# 8079                  1.0                    3.0
#
# [8080 rows x 9 columns]

# %%
## Model Training

from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
import numpy as np
def evaluate_model(true, predicted):
    mae = mean_absolute_error(true, predicted)
    mse = mean_squared_error(true, predicted)
    rmse = np.sqrt(mean_squared_error(true, predicted))
    r2_square = r2_score(true, predicted)
    return mae, rmse, r2_square

# %%
## Train multiple models

models={
    'LinearRegression':LinearRegression(),
    'Lasso':Lasso(),
    'Ridge':Ridge(),
    'Elasticnet':ElasticNet()
}

# %%
trained_model_list=[]
model_list=[]
r2_list=[]

# %%
list(models)
# Out:
# ['LinearRegression', 'Lasso', 'Ridge', 'Elasticnet']

# %%
for i in range(len(list(models))):
    model=list(models.values())[i]
    print(model)
# Out:
# LinearRegression()
# Lasso()
# Ridge()
# ElasticNet()

# %%
models.keys()
# Out:
# dict_keys(['LinearRegression', 'Lasso', 'Ridge', 'Elasticnet'])

# %%
models.values()
# Out:
# dict_values([LinearRegression(), Lasso(), Ridge(), ElasticNet()])

# %%
for i in range(len(list(models))):
    model=list(models.values())[i]
    model.fit(x_train,y_train)

    #Make Predictions
    y_pred=model.predict(x_test)

    #this is a validation(test) score
    mae, rmse, r2_square=evaluate_model(y_test,y_pred)

    print(list(models.keys())[i])
    model_list.append(list(models.keys())[i])

    print('Model Training Performance')
    print("RMSE:",rmse)
    print("MAE:",mae)
    print("R2 score",r2_square*100)

    r2_list.append(r2_square)
    
    print('='*35)
    print('\n')
# Out:
# LinearRegression
# Model Training Performance
# RMSE: 1473.1030911396006
# MAE: 820.6695441677318
# R2 score 86.82979623458998
# ===================================
# c:\fsdmendtoend\env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.236e+08, tolerance: 3.027e+07
#   model = cd_fast.enet_coordinate_descent(
# Lasso
# Model Training Performance
# RMSE: 1304.8045146075453
# MAE: 817.4092157988729
# R2 score 89.6672216350785
# ===================================
#
#
# Ridge
# Model Training Performance
# RMSE: 1453.663691164996
# MAE: 820.4570669532624
# R2 score 87.17509671740406
# ===================================
#
#
# Elasticnet
# Model Training Performance
# RMSE: 1646.2942714650928
# MAE: 1075.6713298991936
# R2 score 83.55093765694106
# ===================================

# %%
trained_model_list
# Out:
# []

# %%
model_list
# Out:
# ['LinearRegression', 'Lasso', 'Ridge', 'Elasticnet']

# %%
r2_list
# Out:
# [0.8682979623458997, 0.896672216350785, 0.8717509671740407, 0.8355093765694106]
